# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime
# Import the API key.
from config import weather_api_key
# Import the time module
import time
from scipy.stats import linregress
import gmaps
import random

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# # Starting URL for Weather Map API Call.
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_weather_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | rosetta
# Processing Record 4 of Set 1 | north bend
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | bhag
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | changji
# Processing Record 11 of Set 1 | oussouye
# Processing Record 12 of Set 1 | camopi
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | svetlogorsk
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | bogovina
# Processing Record 17 of Set 1 | rochegda
# Processing Record 18 of Set 1 | hami
# Processing Record 19 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 1 | karasjok
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | airai
# Processing Record 24 of Set 1 | pangnirtung
# Processing Record 25 of Set 1 | conceicao do araguaia
# Processing Record 26 of Set 1 | broome
# Processing Record 27 of Set 1 | etchoropo
# Processing Record 28 of Set 1 | riyadh
# Processing Record 29 of Set 1 | teya
# Processing Record 30 of Set 1 | awjilah
# Processing Record 31 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 1 | komsomolskiy
# Processing Record 33 of Set 1 | hamilton
# Processing Record 34 of Set 1 | aswan
# Processing Record 35 of Set 1 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 36 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | hasaki
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | santiago
# Processing Record 47 of Set 1 | viedma
# Processing Record 48 of Set 1 | hobyo
# Processing Record 49 of Set 1 | vardo
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | shingu
# Processing Record 3 of Set 2 | chase
# Processing Record 4 of Set 2 | guerrero negro
# Processing Record 5 of Set 2 | taldan
# Processing Record 6 of Set 2 | chimbote
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | pisco
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | along
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | alyangula
# Processing Record 13 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 2 | lagoa
# Processing Record 15 of Set 2 | longyearbyen
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | arlit
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | kryry
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | opobo
# City not found. Skipping...
# Processing Record 22 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 2 | tommot
# Processing Record 24 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | piranhas
# Processing Record 28 of Set 2 | abrau-dyurso
# Processing Record 29 of Set 2 | tarhunah
# City not found. Skipping...
# Processing Record 30 of Set 2 | zyryanka
# Processing Record 31 of Set 2 | grand-santi
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | kruisfontein
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | aripuana
# Processing Record 37 of Set 2 | champerico
# Processing Record 38 of Set 2 | massaguet
# Processing Record 39 of Set 2 | bengkulu
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | boa vista
# Processing Record 44 of Set 2 | richards bay
# Processing Record 45 of Set 2 | dunedin
# Processing Record 46 of Set 2 | wilmington
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | mihailesti
# Processing Record 49 of Set 2 | minna
# Processing Record 50 of Set 2 | san isidro
# Processing Record 1 of Set 3 | ende
# Processing Record 2 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 3 | kaeo
# Processing Record 4 of Set 3 | kavaratti
# Processing Record 5 of Set 3 | axim
# Processing Record 6 of Set 3 | kondinskoye
# Processing Record 7 of Set 3 | chuy
# Processing Record 8 of Set 3 | lavrentiya
# Processing Record 9 of Set 3 | san patricio
# Processing Record 10 of Set 3 | tromso
# Processing Record 11 of Set 3 | alushta
# Processing Record 12 of Set 3 | barrow
# Processing Record 13 of Set 3 | half moon bay
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | clermont
# Processing Record 18 of Set 3 | noumea
# Processing Record 19 of Set 3 | margate
# Processing Record 20 of Set 3 | tixtla
# City not found. Skipping...
# Processing Record 21 of Set 3 | lompoc
# Processing Record 22 of Set 3 | juxtlahuaca
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | verkhoyansk
# Processing Record 26 of Set 3 | muli
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | grajewo
# Processing Record 29 of Set 3 | pandamatenga
# Processing Record 30 of Set 3 | dergachi
# Processing Record 31 of Set 3 | quatre cocos
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | bulgan
# Processing Record 34 of Set 3 | poum
# Processing Record 35 of Set 3 | naryan-mar
# Processing Record 36 of Set 3 | santa lucia
# Processing Record 37 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 3 | el paujil
# Processing Record 39 of Set 3 | marystown
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | oneonta
# Processing Record 42 of Set 3 | la ronge
# Processing Record 43 of Set 3 | sao gabriel da cachoeira
# Processing Record 44 of Set 3 | guajara-mirim
# City not found. Skipping...
# Processing Record 45 of Set 3 | sakakah
# Processing Record 46 of Set 3 | khasan
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | nadym
# Processing Record 49 of Set 3 | saint george
# Processing Record 50 of Set 3 | avera
# Processing Record 1 of Set 4 | souillac
# Processing Record 2 of Set 4 | nabire
# Processing Record 3 of Set 4 | naze
# Processing Record 4 of Set 4 | muisne
# Processing Record 5 of Set 4 | grand gaube
# Processing Record 6 of Set 4 | paracuru
# Processing Record 7 of Set 4 | henties bay
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | moyale
# Processing Record 10 of Set 4 | cockburn town
# Processing Record 11 of Set 4 | shenjiamen
# Processing Record 12 of Set 4 | fort oglethorpe
# Processing Record 13 of Set 4 | ketchikan
# Processing Record 14 of Set 4 | talnakh
# Processing Record 15 of Set 4 | nalut
# Processing Record 16 of Set 4 | cayenne
# Processing Record 17 of Set 4 | katsuura
# Processing Record 18 of Set 4 | oak ridge
# Processing Record 19 of Set 4 | shelburne
# Processing Record 20 of Set 4 | avarua
# Processing Record 21 of Set 4 | nouakchott
# Processing Record 22 of Set 4 | kotovo
# Processing Record 23 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 4 | namibe
# Processing Record 25 of Set 4 | caruray
# Processing Record 26 of Set 4 | aras
# Processing Record 27 of Set 4 | maniitsoq
# Processing Record 28 of Set 4 | makakilo city
# Processing Record 29 of Set 4 | tilichiki
# Processing Record 30 of Set 4 | camacha
# Processing Record 31 of Set 4 | mingguang
# Processing Record 32 of Set 4 | torbat-e jam
# Processing Record 33 of Set 4 | westport
# Processing Record 34 of Set 4 | morlaix
# Processing Record 35 of Set 4 | klaksvik
# Processing Record 36 of Set 4 | safaga
# Processing Record 37 of Set 4 | pemberton
# Processing Record 38 of Set 4 | koumac
# Processing Record 39 of Set 4 | vero beach
# Processing Record 40 of Set 4 | torbay
# Processing Record 41 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 4 | porto walter
# Processing Record 44 of Set 4 | xinzhou
# Processing Record 45 of Set 4 | egvekinot
# Processing Record 46 of Set 4 | mitchell
# Processing Record 47 of Set 4 | saint-philippe
# Processing Record 48 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 4 | husavik
# Processing Record 50 of Set 4 | yanaul
# Processing Record 1 of Set 5 | bayji
# Processing Record 2 of Set 5 | haines junction
# Processing Record 3 of Set 5 | narsaq
# Processing Record 4 of Set 5 | saint anthony
# Processing Record 5 of Set 5 | surt
# Processing Record 6 of Set 5 | chokurdakh
# Processing Record 7 of Set 5 | namatanai
# Processing Record 8 of Set 5 | uberaba
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | saint-augustin
# Processing Record 11 of Set 5 | hauterive
# Processing Record 12 of Set 5 | katangli
# Processing Record 13 of Set 5 | christchurch
# Processing Record 14 of Set 5 | velikiy ustyug
# Processing Record 15 of Set 5 | cap malheureux
# Processing Record 16 of Set 5 | halifax
# Processing Record 17 of Set 5 | honiara
# Processing Record 18 of Set 5 | parry sound
# Processing Record 19 of Set 5 | tateyama
# Processing Record 20 of Set 5 | itarema
# Processing Record 21 of Set 5 | east london
# Processing Record 22 of Set 5 | kaitangata
# Processing Record 23 of Set 5 | itoman
# Processing Record 24 of Set 5 | gambela
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | arambagh
# Processing Record 27 of Set 5 | solnechnyy
# Processing Record 28 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 5 | waipawa
# Processing Record 30 of Set 5 | nelson bay
# Processing Record 31 of Set 5 | severo-kurilsk
# Processing Record 32 of Set 5 | tshane
# Processing Record 33 of Set 5 | ulladulla
# Processing Record 34 of Set 5 | shamary
# Processing Record 35 of Set 5 | jiuquan
# Processing Record 36 of Set 5 | lydenburg
# Processing Record 37 of Set 5 | gat
# Processing Record 38 of Set 5 | auki
# Processing Record 39 of Set 5 | butaritari
# Processing Record 40 of Set 5 | tighina
# Processing Record 41 of Set 5 | neuquen
# Processing Record 42 of Set 5 | great falls
# Processing Record 43 of Set 5 | kodiak
# Processing Record 44 of Set 5 | singapore
# Processing Record 45 of Set 5 | baiyin
# Processing Record 46 of Set 5 | den helder
# Processing Record 47 of Set 5 | tuktoyaktuk
# Processing Record 48 of Set 5 | faya
# Processing Record 49 of Set 5 | awbari
# Processing Record 50 of Set 5 | faanui
# Processing Record 1 of Set 6 | beyneu
# Processing Record 2 of Set 6 | palmer
# Processing Record 3 of Set 6 | carnarvon
# Processing Record 4 of Set 6 | udachnyy
# Processing Record 5 of Set 6 | barcelos
# Processing Record 6 of Set 6 | manicore
# Processing Record 7 of Set 6 | shenkursk
# Processing Record 8 of Set 6 | yerbogachen
# Processing Record 9 of Set 6 | atambua
# Processing Record 10 of Set 6 | abu dhabi
# Processing Record 11 of Set 6 | camana
# Processing Record 12 of Set 6 | jieshi
# Processing Record 13 of Set 6 | ixtapa
# Processing Record 14 of Set 6 | tiassale
# Processing Record 15 of Set 6 | bathsheba
# Processing Record 16 of Set 6 | iqaluit
# Processing Record 17 of Set 6 | tondon
# Processing Record 18 of Set 6 | verkhnyaya inta
# Processing Record 19 of Set 6 | lata
# Processing Record 20 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 21 of Set 6 | roald
# Processing Record 22 of Set 6 | nome
# Processing Record 23 of Set 6 | bud
# Processing Record 24 of Set 6 | eureka
# Processing Record 25 of Set 6 | eyl
# Processing Record 26 of Set 6 | beringovskiy
# Processing Record 27 of Set 6 | provideniya
# Processing Record 28 of Set 6 | sorland
# Processing Record 29 of Set 6 | tlahualilo
# City not found. Skipping...
# Processing Record 30 of Set 6 | khandyga
# Processing Record 31 of Set 6 | oranjemund
# Processing Record 32 of Set 6 | xichang
# Processing Record 33 of Set 6 | sobolevo
# Processing Record 34 of Set 6 | puerto boyaca
# Processing Record 35 of Set 6 | benguela
# Processing Record 36 of Set 6 | owase
# Processing Record 37 of Set 6 | tuatapere
# Processing Record 38 of Set 6 | ivankiv
# Processing Record 39 of Set 6 | fort-shevchenko
# Processing Record 40 of Set 6 | yulara
# Processing Record 41 of Set 6 | atuona
# Processing Record 42 of Set 6 | skibbereen
# Processing Record 43 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 6 | tubuala
# Processing Record 45 of Set 6 | antofagasta
# Processing Record 46 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 6 | ribeira grande
# Processing Record 48 of Set 6 | kutum
# Processing Record 49 of Set 6 | sterling
# Processing Record 50 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 7 | banjar
# Processing Record 2 of Set 7 | derzhavinsk
# Processing Record 3 of Set 7 | excelsior springs
# Processing Record 4 of Set 7 | juneau
# Processing Record 5 of Set 7 | puerto colombia
# Processing Record 6 of Set 7 | acapulco
# Processing Record 7 of Set 7 | robertsport
# Processing Record 8 of Set 7 | ilulissat
# Processing Record 9 of Set 7 | yelizovo
# Processing Record 10 of Set 7 | ilebo
# Processing Record 11 of Set 7 | skjervoy
# Processing Record 12 of Set 7 | okhotsk
# Processing Record 13 of Set 7 | pitimbu
# Processing Record 14 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 7 | eidsvag
# Processing Record 16 of Set 7 | port lavaca
# Processing Record 17 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 7 | mar del plata
# Processing Record 19 of Set 7 | bonthe
# Processing Record 20 of Set 7 | sharanga
# Processing Record 21 of Set 7 | khorramshahr
# Processing Record 22 of Set 7 | luanda
# Processing Record 23 of Set 7 | fairview
# Processing Record 24 of Set 7 | vangaindrano
# Processing Record 25 of Set 7 | mago
# Processing Record 26 of Set 7 | iwaki
# Processing Record 27 of Set 7 | portland
# Processing Record 28 of Set 7 | padang
# Processing Record 29 of Set 7 | okha
# Processing Record 30 of Set 7 | kalmunai
# Processing Record 31 of Set 7 | kondagaon
# Processing Record 32 of Set 7 | nishihara
# Processing Record 33 of Set 7 | revadanda
# Processing Record 34 of Set 7 | polson
# Processing Record 35 of Set 7 | nanchang
# Processing Record 36 of Set 7 | sigli
# Processing Record 37 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 7 | uruguaiana
# Processing Record 39 of Set 7 | asau
# Processing Record 40 of Set 7 | nianzishan
# Processing Record 41 of Set 7 | porto novo
# Processing Record 42 of Set 7 | myrtle beach
# Processing Record 43 of Set 7 | vuktyl
# Processing Record 44 of Set 7 | ratnagiri
# Processing Record 45 of Set 7 | tiksi
# Processing Record 46 of Set 7 | sao filipe
# Processing Record 47 of Set 7 | tsumeb
# Processing Record 48 of Set 7 | isangel
# Processing Record 49 of Set 7 | jumla
# Processing Record 50 of Set 7 | tefe
# Processing Record 1 of Set 8 | mpika
# Processing Record 2 of Set 8 | nouadhibou
# Processing Record 3 of Set 8 | fortuna
# Processing Record 4 of Set 8 | tome
# Processing Record 5 of Set 8 | japura
# Processing Record 6 of Set 8 | langsa
# Processing Record 7 of Set 8 | yumen
# Processing Record 8 of Set 8 | semnan
# Processing Record 9 of Set 8 | poya
# Processing Record 10 of Set 8 | vostok
# Processing Record 11 of Set 8 | illapel
# Processing Record 12 of Set 8 | tevaitoa
# Processing Record 13 of Set 8 | cordele
# Processing Record 14 of Set 8 | jalu
# Processing Record 15 of Set 8 | namtsy
# Processing Record 16 of Set 8 | vila velha
# Processing Record 17 of Set 8 | gomel
# Processing Record 18 of Set 8 | corrente
# Processing Record 19 of Set 8 | najran
# Processing Record 20 of Set 8 | miquelon
# Processing Record 21 of Set 8 | sept-iles
# Processing Record 22 of Set 8 | salalah
# Processing Record 23 of Set 8 | amapa
# Processing Record 24 of Set 8 | ngunguru
# Processing Record 25 of Set 8 | grindavik
# Processing Record 26 of Set 8 | staryye atagi
# Processing Record 27 of Set 8 | brinkovskaya
# Processing Record 28 of Set 8 | cabedelo
# Processing Record 29 of Set 8 | koszalin
# Processing Record 30 of Set 8 | dingle
# Processing Record 31 of Set 8 | natal
# Processing Record 32 of Set 8 | kenai
# Processing Record 33 of Set 8 | sheltozero
# Processing Record 34 of Set 8 | bubaque
# Processing Record 35 of Set 8 | yuli
# Processing Record 36 of Set 8 | bam
# Processing Record 37 of Set 8 | fort walton beach
# Processing Record 38 of Set 8 | morgan city
# Processing Record 39 of Set 8 | geraldton
# Processing Record 40 of Set 8 | erdenet
# Processing Record 41 of Set 8 | adrar
# Processing Record 42 of Set 8 | anadyr
# Processing Record 43 of Set 8 | trento
# Processing Record 44 of Set 8 | kununurra
# Processing Record 45 of Set 8 | lorengau
# Processing Record 46 of Set 8 | dargaville
# Processing Record 47 of Set 8 | laichingen
# Processing Record 48 of Set 8 | sola
# Processing Record 49 of Set 8 | bilma
# Processing Record 50 of Set 8 | san ramon
# Processing Record 1 of Set 9 | bonavista
# Processing Record 2 of Set 9 | tessalit
# Processing Record 3 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 9 | jacqueville
# Processing Record 5 of Set 9 | la union
# Processing Record 6 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 9 | ouesso
# Processing Record 8 of Set 9 | plouzane
# Processing Record 9 of Set 9 | pahrump
# Processing Record 10 of Set 9 | wadi maliz
# Processing Record 11 of Set 9 | banda aceh
# Processing Record 12 of Set 9 | pokosnoye
# Processing Record 13 of Set 9 | sur
# Processing Record 14 of Set 9 | kismayo
# Processing Record 15 of Set 9 | samaipata
# Processing Record 16 of Set 9 | kungurtug
# Processing Record 17 of Set 9 | college
# Processing Record 18 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 9 | mana
# Processing Record 20 of Set 9 | vanavara
# Processing Record 21 of Set 9 | jiazi
# Processing Record 22 of Set 9 | novorzhev
# Processing Record 23 of Set 9 | garm
# City not found. Skipping...
# Processing Record 24 of Set 9 | polyarnyy
# Processing Record 25 of Set 9 | altay
# Processing Record 26 of Set 9 | chegdomyn
# Processing Record 27 of Set 9 | moose factory
# Processing Record 28 of Set 9 | soyo
# Processing Record 29 of Set 9 | suntar
# Processing Record 30 of Set 9 | talaya
# Processing Record 31 of Set 9 | esil
# Processing Record 32 of Set 9 | batagay-alyta
# Processing Record 33 of Set 9 | ucluelet
# Processing Record 34 of Set 9 | sychevka
# Processing Record 35 of Set 9 | raudeberg
# Processing Record 36 of Set 9 | angra
# City not found. Skipping...
# Processing Record 37 of Set 9 | esperance
# Processing Record 38 of Set 9 | homer
# Processing Record 39 of Set 9 | dwarka
# Processing Record 40 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 9 | lima
# Processing Record 42 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 9 | clyde river
# Processing Record 44 of Set 9 | santa marta
# Processing Record 45 of Set 9 | dibulla
# Processing Record 46 of Set 9 | sambava
# Processing Record 47 of Set 9 | singkang
# Processing Record 48 of Set 9 | havelock
# Processing Record 49 of Set 9 | snasa
# Processing Record 50 of Set 9 | rio gallegos
# Processing Record 1 of Set 10 | qaqortoq
# Processing Record 2 of Set 10 | alofi
# Processing Record 3 of Set 10 | manokwari
# Processing Record 4 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 10 | maridi
# Processing Record 6 of Set 10 | kahului
# Processing Record 7 of Set 10 | lethem
# Processing Record 8 of Set 10 | bambous virieux
# Processing Record 9 of Set 10 | lewistown
# Processing Record 10 of Set 10 | karakose
# City not found. Skipping...
# Processing Record 11 of Set 10 | chapais
# Processing Record 12 of Set 10 | buraydah
# Processing Record 13 of Set 10 | lushunkou
# City not found. Skipping...
# Processing Record 14 of Set 10 | yantongshan
# Processing Record 15 of Set 10 | provost
# Processing Record 16 of Set 10 | cobija
# Processing Record 17 of Set 10 | bambanglipuro
# Processing Record 18 of Set 10 | mutsu
# Processing Record 19 of Set 10 | dandong
# Processing Record 20 of Set 10 | ouadda
# Processing Record 21 of Set 10 | kholodnyy
# Processing Record 22 of Set 10 | kodinsk
# Processing Record 23 of Set 10 | nisia floresta
# Processing Record 24 of Set 10 | sunrise manor
# Processing Record 25 of Set 10 | zhetysay
# Processing Record 26 of Set 10 | aykhal
# Processing Record 27 of Set 10 | melo
# Processing Record 28 of Set 10 | miami
# Processing Record 29 of Set 10 | sovetskiy
# Processing Record 30 of Set 10 | polunochnoye
# Processing Record 31 of Set 10 | oktyabrskiy
# Processing Record 32 of Set 10 | petropavlovka
# Processing Record 33 of Set 10 | bururi
# Processing Record 34 of Set 10 | marawi
# Processing Record 35 of Set 10 | sabang
# Processing Record 36 of Set 10 | ilinskiy
# Processing Record 37 of Set 10 | moree
# Processing Record 38 of Set 10 | mittagong
# Processing Record 39 of Set 10 | kieta
# Processing Record 40 of Set 10 | tampere
# Processing Record 41 of Set 10 | yar-sale
# Processing Record 42 of Set 10 | takaka
# Processing Record 43 of Set 10 | jiwani
# Processing Record 44 of Set 10 | sungaipenuh
# Processing Record 45 of Set 10 | sao joao da barra
# Processing Record 46 of Set 10 | muncar
# Processing Record 47 of Set 10 | sao felix do xingu
# Processing Record 48 of Set 10 | londoko
# Processing Record 49 of Set 10 | durango
# Processing Record 50 of Set 10 | fuerte olimpo
# Processing Record 1 of Set 11 | bachaquero
# Processing Record 2 of Set 11 | vila franca do campo
# Processing Record 3 of Set 11 | contamana
# Processing Record 4 of Set 11 | pitkyaranta
# Processing Record 5 of Set 11 | zatoka
# Processing Record 6 of Set 11 | the valley
# Processing Record 7 of Set 11 | hwange
# Processing Record 8 of Set 11 | yuzhno-kurilsk
# Processing Record 9 of Set 11 | rognan
# Processing Record 10 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 11 | bhuban
# Processing Record 12 of Set 11 | caravelas
# Processing Record 13 of Set 11 | hofn
# Processing Record 14 of Set 11 | uvira
# Processing Record 15 of Set 11 | nizhneangarsk
# Processing Record 16 of Set 11 | ancud
# Processing Record 17 of Set 11 | zabaykalsk
# Processing Record 18 of Set 11 | tezu
# Processing Record 19 of Set 11 | muri
# Processing Record 20 of Set 11 | marsh harbour
# Processing Record 21 of Set 11 | yining
# Processing Record 22 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 11 | kainantu
# Processing Record 24 of Set 11 | barranca
# Processing Record 25 of Set 11 | mwingi
# Processing Record 26 of Set 11 | codrington
# Processing Record 27 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 28 of Set 11 | cruz alta
# Processing Record 29 of Set 11 | lokken verk
# City not found. Skipping...
# Processing Record 30 of Set 11 | katherine
# Processing Record 31 of Set 11 | nandyal
# Processing Record 32 of Set 11 | kijang
# Processing Record 33 of Set 11 | fukue
# Processing Record 34 of Set 11 | olinda
# Processing Record 35 of Set 11 | te anau
# Processing Record 36 of Set 11 | mehamn
# Processing Record 37 of Set 11 | ola
# Processing Record 38 of Set 11 | gravelbourg
# Processing Record 39 of Set 11 | ahipara
# Processing Record 40 of Set 11 | vestmannaeyjar
# Processing Record 41 of Set 11 | pedernales
# Processing Record 42 of Set 11 | coquimbo
# Processing Record 43 of Set 11 | bhiwandi
# Processing Record 44 of Set 11 | aklavik
# Processing Record 45 of Set 11 | christiana
# Processing Record 46 of Set 11 | ogden
# Processing Record 47 of Set 11 | gazojak
# Processing Record 48 of Set 11 | kavieng
# Processing Record 49 of Set 11 | pitea
# Processing Record 50 of Set 11 | lakes entrance
# Processing Record 1 of Set 12 | jaroslaw
# Processing Record 2 of Set 12 | havoysund
# Processing Record 3 of Set 12 | chumikan
# Processing Record 4 of Set 12 | nipawin
# Processing Record 5 of Set 12 | fuling
# Processing Record 6 of Set 12 | betong
# Processing Record 7 of Set 12 | whitehorse
# Processing Record 8 of Set 12 | chiang khong
# Processing Record 9 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 10 of Set 12 | umm kaddadah
# Processing Record 11 of Set 12 | constitucion
# Processing Record 12 of Set 12 | thunder bay
# Processing Record 13 of Set 12 | bereda
# Processing Record 14 of Set 12 | san andres
# Processing Record 15 of Set 12 | comal
# Processing Record 16 of Set 12 | windsor
# Processing Record 17 of Set 12 | sidrolandia
# Processing Record 18 of Set 12 | nanortalik
# Processing Record 19 of Set 12 | murdochville
# Processing Record 20 of Set 12 | saint-francois
# Processing Record 21 of Set 12 | lahaina
# Processing Record 22 of Set 12 | ewa beach
# Processing Record 23 of Set 12 | nikki
# Processing Record 24 of Set 12 | palu
# Processing Record 25 of Set 12 | mount gambier
# Processing Record 26 of Set 12 | santiago del estero
# Processing Record 27 of Set 12 | creston
# Processing Record 28 of Set 12 | aban
# Processing Record 29 of Set 12 | zajecar
# Processing Record 30 of Set 12 | leningradskiy
# Processing Record 31 of Set 12 | ayan
# Processing Record 32 of Set 12 | prince rupert
# Processing Record 33 of Set 12 | tazovskiy
# Processing Record 34 of Set 12 | kupang
# Processing Record 35 of Set 12 | sao miguel do guama
# Processing Record 36 of Set 12 | hovd
# Processing Record 37 of Set 12 | tucuma
# Processing Record 38 of Set 12 | krasnoarmeysk
# Processing Record 39 of Set 12 | twentynine palms
# Processing Record 40 of Set 12 | samarai
# Processing Record 41 of Set 12 | mizdah
# Processing Record 42 of Set 12 | petukhovo
# Processing Record 43 of Set 12 | kirakira
# Processing Record 44 of Set 12 | urfa
# City not found. Skipping...
# Processing Record 45 of Set 12 | srednekolymsk
# Processing Record 46 of Set 12 | werda
# Processing Record 47 of Set 12 | sumenep
# Processing Record 48 of Set 12 | phalodi
# Processing Record 49 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 50 of Set 12 | monteagudo
# Processing Record 1 of Set 13 | fountain hills
# Processing Record 2 of Set 13 | nambucca heads
# Processing Record 3 of Set 13 | pirpirituba
# Processing Record 4 of Set 13 | rawson
# Processing Record 5 of Set 13 | cabo san lucas
# Processing Record 6 of Set 13 | mosquera
# Processing Record 7 of Set 13 | shaoguan
# Processing Record 8 of Set 13 | kota kinabalu
# Processing Record 9 of Set 13 | luwingu
# Processing Record 10 of Set 13 | bara
# Processing Record 11 of Set 13 | mount isa
# Processing Record 12 of Set 13 | pustoshka
# Processing Record 13 of Set 13 | odessa
# Processing Record 14 of Set 13 | pierre
# Processing Record 15 of Set 13 | vitimskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | bull savanna
# Processing Record 17 of Set 13 | isetskoye
# Processing Record 18 of Set 13 | boshnyakovo
# Processing Record 19 of Set 13 | anito
# Processing Record 20 of Set 13 | binzhou
# Processing Record 21 of Set 13 | olafsvik
# Processing Record 22 of Set 13 | aljezur
# Processing Record 23 of Set 13 | peniche
# Processing Record 24 of Set 13 | maarianhamina
# Processing Record 25 of Set 13 | kolyshley
# Processing Record 26 of Set 13 | nykobing
# City not found. Skipping...
# Processing Record 27 of Set 13 | flinders
# Processing Record 28 of Set 13 | atar
# Processing Record 29 of Set 13 | beloha
# Processing Record 30 of Set 13 | aksu
# Processing Record 31 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 32 of Set 13 | zabinka
# City not found. Skipping...
# Processing Record 33 of Set 13 | arica
# Processing Record 34 of Set 13 | necochea
# Processing Record 35 of Set 13 | puerto quijarro
# Processing Record 36 of Set 13 | thinadhoo
# Processing Record 37 of Set 13 | kiunga
# Processing Record 38 of Set 13 | myingyan
# Processing Record 39 of Set 13 | santa cruz
# Processing Record 40 of Set 13 | chihuahua
# Processing Record 41 of Set 13 | byron bay
# Processing Record 42 of Set 13 | nchelenge
# Processing Record 43 of Set 13 | kudahuvadhoo
# Processing Record 44 of Set 13 | maneadero
# Processing Record 45 of Set 13 | simao
# Processing Record 46 of Set 13 | hurricane
# Processing Record 47 of Set 13 | bako
# Processing Record 48 of Set 13 | gwadar
# Processing Record 49 of Set 13 | hervey bay
# Processing Record 50 of Set 13 | koutiala
# Processing Record 1 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 2 of Set 14 | turmalina
# Processing Record 3 of Set 14 | kulhudhuffushi
# Processing Record 4 of Set 14 | soanierana ivongo
# Processing Record 5 of Set 14 | tarko-sale
# Processing Record 6 of Set 14 | fort beaufort
# Processing Record 7 of Set 14 | gilgit
# Processing Record 8 of Set 14 | honggang
# Processing Record 9 of Set 14 | santa cruz del sur
# Processing Record 10 of Set 14 | lichtenburg
# Processing Record 11 of Set 14 | cairns
# Processing Record 12 of Set 14 | vao
# Processing Record 13 of Set 14 | wembley
# Processing Record 14 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 14 | simi
# Processing Record 16 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 14 | raymond
# Processing Record 18 of Set 14 | pak phanang
# Processing Record 19 of Set 14 | tokur
# Processing Record 20 of Set 14 | vila
# Processing Record 21 of Set 14 | hambantota
# Processing Record 22 of Set 14 | bobo dioulasso
# Processing Record 23 of Set 14 | aketi
# Processing Record 24 of Set 14 | perrysburg
# Processing Record 25 of Set 14 | vidor
# Processing Record 26 of Set 14 | yaan
# Processing Record 27 of Set 14 | marfino
# Processing Record 28 of Set 14 | katikati
# Processing Record 29 of Set 14 | ginda
# Processing Record 30 of Set 14 | ponta delgada
# Processing Record 31 of Set 14 | kenora
# Processing Record 32 of Set 14 | tonantins
# Processing Record 33 of Set 14 | anchorage
# Processing Record 34 of Set 14 | vavuniya
# Processing Record 35 of Set 14 | cabinda
# Processing Record 36 of Set 14 | prince albert
# Processing Record 37 of Set 14 | berlevag
# Processing Record 38 of Set 14 | yefira
# City not found. Skipping...
# Processing Record 39 of Set 14 | san carlos de bariloche
# Processing Record 40 of Set 14 | xiangxiang
# Processing Record 41 of Set 14 | puerto suarez
# Processing Record 42 of Set 14 | alghero
# Processing Record 43 of Set 14 | dhemaji
# Processing Record 44 of Set 14 | asha
# Processing Record 45 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 14 | akyab
# Processing Record 47 of Set 14 | mandurah
# Processing Record 48 of Set 14 | harper
# Processing Record 49 of Set 14 | conde
# Processing Record 50 of Set 14 | oranjestad
# Processing Record 1 of Set 15 | hongan
# City not found. Skipping...
# Processing Record 2 of Set 15 | bafra
# Processing Record 3 of Set 15 | touros
# Processing Record 4 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 15 | usinsk
# Processing Record 6 of Set 15 | saint-vallier
# Processing Record 7 of Set 15 | puerto escondido
# Processing Record 8 of Set 15 | somanda
# Processing Record 9 of Set 15 | balkanabat
# Processing Record 10 of Set 15 | iskateley
# Processing Record 11 of Set 15 | mananjary
# Processing Record 12 of Set 15 | correia pinto
# Processing Record 13 of Set 15 | ormara
# Processing Record 14 of Set 15 | kars
# Processing Record 15 of Set 15 | alta floresta
# Processing Record 16 of Set 15 | watertown
# Processing Record 17 of Set 15 | laureles
# Processing Record 18 of Set 15 | bilibino
# Processing Record 19 of Set 15 | linqiong
# Processing Record 20 of Set 15 | tunggol
# Processing Record 21 of Set 15 | valdez
# Processing Record 22 of Set 15 | laguna
# Processing Record 23 of Set 15 | micheweni
# Processing Record 24 of Set 15 | evensk
# Processing Record 25 of Set 15 | manggar
# Processing Record 26 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 27 of Set 15 | guamuchil
# Processing Record 28 of Set 15 | port lincoln
# Processing Record 29 of Set 15 | mae sai
# Processing Record 30 of Set 15 | arman
# Processing Record 31 of Set 15 | dalbandin
# Processing Record 32 of Set 15 | coahuayana
# Processing Record 33 of Set 15 | gohand
# Processing Record 34 of Set 15 | mmabatho
# Processing Record 35 of Set 15 | zaraza
# Processing Record 36 of Set 15 | broken hill
# Processing Record 37 of Set 15 | niquero
# Processing Record 38 of Set 15 | road town
# Processing Record 39 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 40 of Set 15 | ramnicelu
# Processing Record 41 of Set 15 | wajir
# Processing Record 42 of Set 15 | waingapu
# Processing Record 43 of Set 15 | babynino
# Processing Record 44 of Set 15 | tugulym
# Processing Record 45 of Set 15 | saint quentin
# City not found. Skipping...
# Processing Record 46 of Set 15 | jimeta
# Processing Record 47 of Set 15 | maryborough
# Processing Record 48 of Set 15 | sorata
# Processing Record 49 of Set 15 | moyamba
# Processing Record 50 of Set 15 | siraha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# city_data = []

# city = cities[0]

# city_url = url + "&q=" + city.replace(" ","+")

# #Run an API request for one city
# city_weather = requests.get(city_url).json()
# #Parse out the data
# city_lat = city_weather["coord"]["lat"]
# city_lon = city_weather["coord"]["lon"]
# city_max_temp = city_weather["main"]["temp_max"]
# city_humidity = city_weather["main"]["humidity"]
# city_clouds = city_weather["clouds"]["all"]
# city_wind = city_weather["wind"]["speed"]
# city_country = city_weather["sys"]["country"]
# city_weather_description = city_weather["weather"][0]["description"]

# #Append city info into city data
# city_data.append({"City": city.title(),
#                   "Lat": city_lat,
#                   "Lon": city_lon,
#                   "Max Temp": city_max_temp,
#                   "Current Description": city_weather_description,
#                   "Humidity": city_humidity,
#                   "Cloudiness": city_clouds,
#                   "Wind Speed": city_wind,
#                   "Country": city_country})
# print(len(city_data))

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng Current Description  Max Temp  Humidity  \
# 0    Jamestown  42.10  -79.24     overcast clouds     44.01        70
# 1   Bredasdorp -34.53   20.04    scattered clouds     66.20        72
# 2      Rosetta  31.40   30.42          few clouds     73.40        60
# 3   North Bend  43.41 -124.22     overcast clouds     54.00       100
# 4    Busselton -33.65  115.33       broken clouds     59.00        49
# 5    Saskylakh  71.92  114.08          light snow     16.79        95
# 6         Bhag  29.04   67.82           clear sky     74.46        17
# 7  Yellowknife  62.46 -114.35    scattered clouds     24.80        73
# 8      Changji  44.02   87.32           clear sky     44.60        75
# 9     Oussouye  12.48  -16.55          few clouds     95.00        70
#
#    Cloudiness  Wind Speed Country                 Date
# 0          90        3.36      US  2020-10-24 17:17:08
# 1          39        9.17      ZA  2020-10-24 17:17:08
# 2          20        4.70      EG  2020-10-24 17:17:08
# 3          90        3.36      US  2020-10-24 17:17:08
# 4          69       12.12      AU  2020-10-24 17:17:08
# 5         100       23.71      RU  2020-10-24 17:17:08
# 6           0        3.29      PK  2020-10-24 17:17:09
# 7          40        9.17      CA  2020-10-24 17:15:03
# 8           0        2.24      CN  2020-10-24 17:17:09
# 9          20        4.70      SN  2020-10-24 17:17:09

# %%
arranged_city_data = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[arranged_city_data]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
